# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapurna0220/11239A066_OPENCV/blob/main/Experiment4_(4_Drawing_Functions).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Draw a line on an image

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

img = cv2.imread(list(files.upload().keys())[0])

cv2.line(img, (50,50), (200,200), (0,255,0), 2)
cv2_imshow(img)
# Out:
#      <input type="file" id="files-e24ced17-3fa7-441f-b328-8858fffc92fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e24ced17-3fa7-441f-b328-8858fffc92fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2. Draw a rectangle and circle

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

img = cv2.imread(list(files.upload().keys())[0])

cv2.rectangle(img, (50,50), (200,200), (145,0,0), 2)
cv2.circle(img, (150,150), 50, (0,0,255), 2)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-76fffaab-a25f-4b4d-99f7-17e0b71944ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76fffaab-a25f-4b4d-99f7-17e0b71944ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3. Draw multiple geometric shapes

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

img = cv2.imread(list(files.upload().keys())[0])

cv2.line(img,(10,10),(200,10),(255,0,0),2)
cv2.rectangle(img,(50,50),(150,150),(0,255,0),2)
cv2.circle(img,(200,200),40,(0,0,255),2)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-9074c779-8b2f-4b07-a1f4-607e1d8e9a4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9074c779-8b2f-4b07-a1f4-607e1d8e9a4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 4. Write text on an image

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

img = cv2.imread(list(files.upload().keys())[0])

cv2.putText(img, "Hello", (50,100),
            cv2.FONT_HERSHEY_SIMPLEX, 1,
            (255,0,0), 2)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-d78ae329-a08a-4f45-a9d7-ed2875a2c2b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d78ae329-a08a-4f45-a9d7-ed2875a2c2b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 5. Create a simple drawing canvas

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

canvas = np.zeros((300,300,3), dtype='uint8')

cv2.line(canvas,(0,0),(300,300),(255,255,255),2)
cv2.circle(canvas,(150,150),50,(0,255,0),2)

cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
